# %%
path = 'C:/Users/isaac/Dropbox/Apps/ShareLaTeX/information_lawyer_quality'

# %%
import pandas as pd

# %%
# Read data 
data = pd.read_csv(path + '/_aux/lawyer_scores_p3.csv') 
print(data.shape)
data.columns
# Out:
# (2730, 75)
# Index(['id_actor', 'junta', 'exp', 'anio', 'nombre_actor', 'tipo_abogado',
#        'reclutamiento', 'giro_empresa', 'trabajador_confianza',
#        'sueldo_estadistico', 'periodicidad_sueldo_estadistic', 'tipo_jornada',
#        'numero_horas_laboradas', 'periodicidad_horas_laboradas',
#        'reinstalacion', 'indemnizacion_constitucional', 'salarios_caidos',
#        'prima_antiguedad', 'vacaciones', 'prima_vacacional', 'aguinaldo',
#        'horas_extra', 'indemnizacion_20_dias_anio_ser', 'prima_dominical',
#        'descanso_semanal', 'descanso_obligatorio', 'cuotas_sar_imss_info',
#        'utilidades', 'salarios_devengados_numero_dia', 'nulidad',
#        'accion_principal', 'tipo_prevencion', 'derecho_propio_c_clv',
#        'giro_defendant_c_clv', 'num_demandados_totales',
#        'num_demandados_completos', 'num_abogados_proemio',
#        'num_abogados_proemio_completos', 'incrementos_sal_c_clv',
#        'contrato_c_clv', 'lugar_trabajo_c_clv', 'horario_inicio_jornada_c_clv',
#        'horario_fin_jornada_c_clv', 'especifican_dias_c_clv',
#        'salario_int_clv', 'periodo_sal_int_clv', 'fecha_despido_c_clv',
#        'lugar_despido_c_clv', 'motivo_despido_c_clv', 'cargo_despide_clv',
#        'presentado_tiempo_forma_c_clv', 'personalidad_c_clv',
#        'firma_trabajador_c_clv', 'estatus', 'modo_termino', 'tratamiento',
#        'fecha_demanda', 'fecha_termino', 'cantidad1', 'cantidad2', 'abogado',
#        'calif_rubro_proemio', 'just_rubro_proemio', 'calif_prestaciones',
#        'just_prestaciones', 'calif_hechos', 'just_hechos', 'calif_derechos',
#        'just_derechos', 'calif_puntos_petitorios', 'just_puntos_petitorios',
#        'total', 'prediccion_a', 'prediccion_b', 'monto'],
#       dtype='object')

# %%
data.describe()
# Out:
#              junta          exp         anio  tipo_abogado  reclutamiento  \
# count  2730.000000  2730.000000  2730.000000   2724.000000    2730.000000
# mean      9.367399  1125.022711  2017.964469      1.668135       0.198168
# std       5.157913   723.178551     0.655767      0.943500       0.398693
# min       1.000000     5.000000  2017.000000      1.000000       0.000000
# 25%       5.000000   532.000000  2018.000000      1.000000       0.000000
# 50%       9.000000  1063.000000  2018.000000      1.000000       0.000000
# 75%      13.000000  1580.250000  2018.000000      3.000000       0.000000
# max      20.000000  3245.000000  2019.000000      3.000000       1.000000
#
#        giro_empresa  trabajador_confianza  sueldo_estadistico  \
# count   2699.000000           2730.000000        2.711000e+03
# mean      54.350871              0.035531        6.925598e+03
# std       12.279798              0.185152        7.572371e+04
# min        0.000000              0.000000        1.738000e+01
# 25%       46.000000              0.000000        2.333300e+02
# 50%       56.000000              0.000000        4.071400e+02
# 75%       56.000000              0.000000        2.000000e+03
# max       93.000000              1.000000        1.862859e+06
#
#        periodicidad_sueldo_estadistic  tipo_jornada  ...     cantidad2  \
# count                     2717.000000   2701.000000  ...     16.000000
# mean                         0.489510      1.296557  ...  14134.151250
# std                          0.896514      0.759010  ...   4846.109285
# min                         -1.000000      0.000000  ...   8000.000000
# 25%                          0.000000      1.000000  ...  10000.000000
# 50%                          0.000000      1.000000  ...  13691.070000
# 75%                          1.000000      1.000000  ...  20000.000000
# max                          3.000000      4.000000  ...  20000.000000
#
#        calif_rubro_proemio  calif_prestaciones  calif_hechos  calif_derechos  \
# count          2730.000000         2730.000000   2730.000000     2730.000000
# mean              8.073260            7.741026      7.557875        7.367033
# std               1.269963            1.338319      1.260697        1.940507
# min               1.000000            1.000000      1.000000        1.000000
# 25%               7.000000            7.000000      7.000000        7.000000
# 50%               8.000000            8.000000      8.000000        8.000000
# 75%               9.000000            9.000000      8.000000        8.000000
# max              10.000000           10.000000     10.000000       10.000000
#
#        calif_puntos_petitorios        total  prediccion_a  prediccion_b  \
# count              2730.000000  2730.000000   2730.000000   2730.000000
# mean                  7.866667     7.450549     55.875824     16.295604
# std                   1.758554     1.137621     17.962390     14.049596
# min                   1.000000     1.000000      0.000000      0.000000
# 25%                   7.000000     7.000000     40.000000      5.000000
# 50%                   8.000000     8.000000     55.000000     10.000000
# 75%                   9.000000     8.000000     70.000000     25.000000
# max                  10.000000    10.000000    100.000000     90.000000
#
#                monto
# count    2730.000000
# mean    31744.180586
# std     41737.395274
# min         0.000000
# 25%     12500.000000
# 50%     20000.000000
# 75%     35000.000000
# max    750000.000000
#
# [8 rows x 60 columns]

# %%
    
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2730 entries, 0 to 2729
# Data columns (total 75 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id_actor                        2644 non-null   object
#  1   junta                           2730 non-null   int64
#  2   exp                             2730 non-null   int64
#  3   anio                            2730 non-null   int64
#  4   nombre_actor                    2730 non-null   object
#  5   tipo_abogado                    2724 non-null   float64
#  6   reclutamiento                   2730 non-null   int64
#  7   giro_empresa                    2699 non-null   float64
#  8   trabajador_confianza            2730 non-null   int64
#  9   sueldo_estadistico              2711 non-null   float64
#  10  periodicidad_sueldo_estadistic  2717 non-null   float64
#  11  tipo_jornada                    2701 non-null   float64
#  12  numero_horas_laboradas          2697 non-null   float64
#  13  periodicidad_horas_laboradas    2700 non-null   float64
#  14  reinstalacion                   2730 non-null   int64
#  15  indemnizacion_constitucional    2730 non-null   int64
#  16  salarios_caidos                 2730 non-null   int64
#  17  prima_antiguedad                2730 non-null   int64
#  18  vacaciones                      2730 non-null   int64
#  19  prima_vacacional                2730 non-null   int64
#  20  aguinaldo                       2730 non-null   int64
#  21  horas_extra                     2730 non-null   int64
#  22  indemnizacion_20_dias_anio_ser  2730 non-null   int64
#  23  prima_dominical                 2730 non-null   int64
#  24  descanso_semanal                2730 non-null   int64
#  25  descanso_obligatorio            2730 non-null   int64
#  26  cuotas_sar_imss_info            2730 non-null   int64
#  27  utilidades                      2730 non-null   int64
#  28  salarios_devengados_numero_dia  1417 non-null   float64
#  29  nulidad                         2730 non-null   int64
#  30  accion_principal                2730 non-null   object
#  31  tipo_prevencion                 85 non-null     object
#  32  derecho_propio_c_clv            2730 non-null   int64
#  33  giro_defendant_c_clv            2730 non-null   int64
#  34  num_demandados_totales          2727 non-null   float64
#  35  num_demandados_completos        2727 non-null   float64
#  36  num_abogados_proemio            2730 non-null   int64
#  37  num_abogados_proemio_completos  2730 non-null   int64
#  38  incrementos_sal_c_clv           2730 non-null   int64
#  39  contrato_c_clv                  2730 non-null   int64
#  40  lugar_trabajo_c_clv             2730 non-null   int64
#  41  horario_inicio_jornada_c_clv    2730 non-null   int64
#  42  horario_fin_jornada_c_clv       2730 non-null   int64
#  43  especifican_dias_c_clv          2730 non-null   int64
#  44  salario_int_clv                 2730 non-null   int64
#  45  periodo_sal_int_clv             2730 non-null   int64
#  46  fecha_despido_c_clv             2730 non-null   int64
#  47  lugar_despido_c_clv             2730 non-null   int64
#  48  motivo_despido_c_clv            2730 non-null   int64
#  49  cargo_despide_clv               2730 non-null   int64
#  50  presentado_tiempo_forma_c_clv   2730 non-null   int64
#  51  personalidad_c_clv              2730 non-null   int64
#  52  firma_trabajador_c_clv          2730 non-null   int64
#  53  estatus                         2644 non-null   object
#  54  modo_termino                    1166 non-null   object
#  55  tratamiento                     2639 non-null   object
#  56  fecha_demanda                   2609 non-null   object
#  57  fecha_termino                   1144 non-null   object
#  58  cantidad1                       800 non-null    float64
#  59  cantidad2                       16 non-null     float64
#  60  abogado                         2730 non-null   object
#  61  calif_rubro_proemio             2730 non-null   int64
#  62  just_rubro_proemio              2730 non-null   object
#  63  calif_prestaciones              2730 non-null   int64
#  64  just_prestaciones               2730 non-null   object
#  65  calif_hechos                    2730 non-null   int64
#  66  just_hechos                     2730 non-null   object
#  67  calif_derechos                  2730 non-null   int64
#  68  just_derechos                   2730 non-null   object
#  69  calif_puntos_petitorios         2730 non-null   int64
#  70  just_puntos_petitorios          2730 non-null   object
#  71  total                           2730 non-null   int64
#  72  prediccion_a                    2730 non-null   int64
#  73  prediccion_b                    2730 non-null   int64
#  74  monto                           2730 non-null   int64
# dtypes: float64(12), int64(48), object(15)
# memory usage: 1.6+ MB

# %%
import numpy as np
X = data[['tipo_abogado',
       'reclutamiento', 'giro_empresa', 'trabajador_confianza',
       'sueldo_estadistico', 'periodicidad_sueldo_estadistic', 'tipo_jornada',
       'numero_horas_laboradas', 'periodicidad_horas_laboradas',
       'reinstalacion', 'indemnizacion_constitucional', 'salarios_caidos',
       'prima_antiguedad', 'vacaciones', 'prima_vacacional', 'aguinaldo',
       'horas_extra', 'indemnizacion_20_dias_anio_ser', 'prima_dominical',
       'descanso_semanal', 'descanso_obligatorio', 'cuotas_sar_imss_info',
       'utilidades', 'salarios_devengados_numero_dia', 'nulidad',
       'accion_principal', 'tipo_prevencion', 'derecho_propio_c_clv',
       'giro_defendant_c_clv', 'num_demandados_totales',
       'num_demandados_completos', 'num_abogados_proemio',
       'num_abogados_proemio_completos', 'incrementos_sal_c_clv',
       'contrato_c_clv', 'lugar_trabajo_c_clv', 'horario_inicio_jornada_c_clv',
       'horario_fin_jornada_c_clv', 'especifican_dias_c_clv',
       'salario_int_clv', 'periodo_sal_int_clv', 'fecha_despido_c_clv',
       'lugar_despido_c_clv', 'motivo_despido_c_clv', 'cargo_despide_clv',
       'presentado_tiempo_forma_c_clv', 'personalidad_c_clv',
       'firma_trabajador_c_clv']]


y = data['total']
y_d = (data['total']>=data['total'].median()).astype(int)

X.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2730 entries, 0 to 2729
# Data columns (total 48 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   tipo_abogado                    2724 non-null   float64
#  1   reclutamiento                   2730 non-null   int64
#  2   giro_empresa                    2699 non-null   float64
#  3   trabajador_confianza            2730 non-null   int64
#  4   sueldo_estadistico              2711 non-null   float64
#  5   periodicidad_sueldo_estadistic  2717 non-null   float64
#  6   tipo_jornada                    2701 non-null   float64
#  7   numero_horas_laboradas          2697 non-null   float64
#  8   periodicidad_horas_laboradas    2700 non-null   float64
#  9   reinstalacion                   2730 non-null   int64
#  10  indemnizacion_constitucional    2730 non-null   int64
#  11  salarios_caidos                 2730 non-null   int64
#  12  prima_antiguedad                2730 non-null   int64
#  13  vacaciones                      2730 non-null   int64
#  14  prima_vacacional                2730 non-null   int64
#  15  aguinaldo                       2730 non-null   int64
#  16  horas_extra                     2730 non-null   int64
#  17  indemnizacion_20_dias_anio_ser  2730 non-null   int64
#  18  prima_dominical                 2730 non-null   int64
#  19  descanso_semanal                2730 non-null   int64
#  20  descanso_obligatorio            2730 non-null   int64
#  21  cuotas_sar_imss_info            2730 non-null   int64
#  22  utilidades                      2730 non-null   int64
#  23  salarios_devengados_numero_dia  1417 non-null   float64
#  24  nulidad                         2730 non-null   int64
#  25  accion_principal                2730 non-null   object
#  26  tipo_prevencion                 85 non-null     object
#  27  derecho_propio_c_clv            2730 non-null   int64
#  28  giro_defendant_c_clv            2730 non-null   int64
#  29  num_demandados_totales          2727 non-null   float64
#  30  num_demandados_completos        2727 non-null   float64
#  31  num_abogados_proemio            2730 non-null   int64
#  32  num_abogados_proemio_completos  2730 non-null   int64
#  33  incrementos_sal_c_clv           2730 non-null   int64
#  34  contrato_c_clv                  2730 non-null   int64
#  35  lugar_trabajo_c_clv             2730 non-null   int64
#  36  horario_inicio_jornada_c_clv    2730 non-null   int64
#  37  horario_fin_jornada_c_clv       2730 non-null   int64
#  38  especifican_dias_c_clv          2730 non-null   int64
#  39  salario_int_clv                 2730 non-null   int64
#  40  periodo_sal_int_clv             2730 non-null   int64
#  41  fecha_despido_c_clv             2730 non-null   int64
#  42  lugar_despido_c_clv             2730 non-null   int64
#  43  motivo_despido_c_clv            2730 non-null   int64
#  44  cargo_despide_clv               2730 non-null   int64
#  45  presentado_tiempo_forma_c_clv   2730 non-null   int64
#  46  personalidad_c_clv              2730 non-null   int64
#  47  firma_trabajador_c_clv          2730 non-null   int64
# dtypes: float64(10), int64(36), object(2)
# memory usage: 1023.9+ KB

# %%
import matplotlib.pyplot as plt
y.value_counts()
plt.hist(y)
# Out:
# (array([  5.,   1.,   6.,  23.,  94., 327., 867., 976., 396.,  35.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
numeric_features = ['sueldo_estadistico', 
                    'numero_horas_laboradas', 
                    'salarios_devengados_numero_dia',
                    'num_demandados_totales',
                    'num_demandados_completos', 
                    'num_abogados_proemio',
                    'num_abogados_proemio_completos']

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('polynomial', PolynomialFeatures(degree=2, include_bias=False)),
    ('scaler', StandardScaler())])

categorical_features = ['tipo_abogado',
                        'giro_empresa',
                        'periodicidad_sueldo_estadistic',
                        'tipo_jornada',
                        'periodicidad_horas_laboradas', 
                        'accion_principal',
                        'tipo_prevencion']

categorical_transformer = OneHotEncoder(handle_unknown='ignore', sparse = False)

binary_features = ['reclutamiento',
                   'trabajador_confianza',
                   'reinstalacion',
                   'indemnizacion_constitucional',
                   'salarios_caidos',
                   'prima_antiguedad',
                   'vacaciones',
                   'prima_vacacional',
                   'aguinaldo',
                   'horas_extra',
                   'indemnizacion_20_dias_anio_ser',
                   'prima_dominical',
                   'descanso_semanal',
                   'descanso_obligatorio',
                   'cuotas_sar_imss_info',
                   'utilidades',
                   'nulidad',
                   'derecho_propio_c_clv',
                   'giro_defendant_c_clv',
                   'incrementos_sal_c_clv',
                   'contrato_c_clv',
                   'lugar_trabajo_c_clv',
                   'horario_inicio_jornada_c_clv',
                   'horario_fin_jornada_c_clv',
                   'especifican_dias_c_clv',
                   'salario_int_clv',
                   'periodo_sal_int_clv',
                   'fecha_despido_c_clv',
                   'lugar_despido_c_clv',
                   'motivo_despido_c_clv',
                   'cargo_despide_clv',
                   'presentado_tiempo_forma_c_clv',
                   'personalidad_c_clv',
                   'firma_trabajador_c_clv']

binary_transformer = Pipeline(steps=[
    ('polynomial', PolynomialFeatures(degree=2, include_bias=False))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
# Preprocesado y modelado
# ==============================================================================
from sklearn.datasets import load_boston
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ParameterGrid
from sklearn.inspection import permutation_importance
import multiprocessing
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

# %%
# Append classifier to preprocessing pipeline.
# Now we have a full prediction pipeline.
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,
                                                    random_state=0)

# %%
benchmark = np.ones(y_test.shape)*y_train.mean()

resultados = pd.DataFrame([
    explained_variance_score(y_test, benchmark, multioutput='uniform_average'),
    r2_score(y_test,benchmark, multioutput='variance_weighted'),
    mean_absolute_error(y_test, benchmark),
    mean_squared_error(y_test, benchmark),
    mean_absolute_percentage_error(y_test, benchmark)]
    )
resultados
# Out:
#               0
# 0  2.220446e-16
# 1 -3.729710e-03
# 2  9.000523e-01
# 3  1.269460e+00
# 4  1.347733e-01

# %%
# Linear Regression
LR = Pipeline(steps=[('preprocessor', preprocessor),
                      ('model', LinearRegression())])
LR.fit(X_train, y_train)


resultados = pd.DataFrame([
    explained_variance_score(y_test, LR.predict(X_test), multioutput='uniform_average'),
    r2_score(y_test,LR.predict(X_test), multioutput='variance_weighted'),
    mean_absolute_error(y_test, LR.predict(X_test)),
    mean_squared_error(y_test, LR.predict(X_test)),
    mean_absolute_percentage_error(y_test, LR.predict(X_test))]
    )
resultados
# Out:
#               0
# 0 -2.311629e+19
# 1 -2.313820e+19
# 2  5.867561e+08
# 3  2.926387e+19
# 4  8.094274e+07

# %%
# Grid de hiperparámetros evaluados
# ==============================================================================
param_grid = {'model__max_features'  : ['auto', 'sqrt', 'log2'],
              'model__max_depth'     : [None, 1, 3, 5, 10, 20],
              'model__subsample'     : [0.5, 1],
              'model__learning_rate' : [0.001, 0.01, 0.1]
             }


GB  = GradientBoostingRegressor(
                        n_estimators        = 1000, 
                        random_state        = 123,
                        # Activación de la parada temprana
                        validation_fraction = 0.1,
                        n_iter_no_change    = 5,
                        tol                 = 0.0001
                    )
# Gradient Boosting
GB = Pipeline(steps=[('preprocessor', preprocessor),
                      ('model', GB)])


# Búsqueda por grid search con validación cruzada
# ==============================================================================
grid = GridSearchCV(GB,
        param_grid = param_grid,
        scoring    = 'neg_root_mean_squared_error',
        n_jobs     = multiprocessing.cpu_count() - 1,
        cv         = RepeatedKFold(n_splits=3, n_repeats=1, random_state=123), 
        refit      = True,
        verbose    = 0,
        return_train_score = True
       )

grid.fit(X = X_train, y = y_train)

# Resultados
# ==============================================================================
resultados = pd.DataFrame(grid.cv_results_)
resultados.filter(regex = '(param.*|mean_t|std_t)') \
    .drop(columns = 'params') \
    .sort_values('mean_test_score', ascending = False) \
    .head(4)
modelo_final = grid.best_estimator_

# %%
resultados = pd.DataFrame([
    explained_variance_score(y_test, modelo_final.predict(X_test), multioutput='uniform_average'),
    r2_score(y_test, modelo_final.predict(X_test), multioutput='variance_weighted'),
    mean_absolute_error(y_test, modelo_final.predict(X_test)),
    mean_squared_error(y_train, modelo_final.predict(X_train)),
    mean_squared_error(y_test, modelo_final.predict(X_test)),
    mean_absolute_percentage_error(y_test, modelo_final.predict(X_test))]
    )
resultados
# Out:
#           0
# 0  0.083094
# 1  0.079524
# 2  0.846812
# 3  1.052534
# 4  1.164165
# 5  0.125718

# %%
importancia = permutation_importance(
                estimator    = modelo_final,
                X            = X_train,
                y            = y_train,
                n_repeats    = 5,
                scoring      = 'neg_root_mean_squared_error',
                n_jobs       = multiprocessing.cpu_count() - 1,
                random_state = 123
             )

# Se almacenan los resultados (media y desviación) en un dataframe
df_importancia = pd.DataFrame(
                    {k: importancia[k] for k in ['importances_mean', 'importances_std']}
                 )
df_importancia['feature'] = X_train.columns
df_importancia.sort_values('importances_mean', ascending=False)
# Out:
#     importances_mean  importances_std                         feature
# 4           0.047816         0.002548              sueldo_estadistico
# 7           0.028839         0.002046          numero_horas_laboradas
# 30          0.023022         0.002061        num_demandados_completos
# 23          0.016959         0.001325  salarios_devengados_numero_dia
# 32          0.016384         0.002961  num_abogados_proemio_completos
# 0           0.014593         0.001113                    tipo_abogado
# 29          0.014378         0.001234          num_demandados_totales
# 2           0.013712         0.001765                    giro_empresa
# 31          0.013594         0.002197            num_abogados_proemio
# 46          0.012046         0.001056              personalidad_c_clv
# 10          0.008899         0.000394    indemnizacion_constitucional
# 42          0.006564         0.001323             lugar_despido_c_clv
# 11          0.006293         0.001230                 salarios_caidos
# 24          0.005354         0.000880                         nulidad
# 28          0.003931         0.001136            giro_defendant_c_clv
# 25          0.003369         0.000566                accion_principal
# 37          0.003302         0.000382       horario_fin_jornada_c_clv
# 5           0.002961         0.000521  periodicidad_sueldo_estadistic
# 34          0.002919         0.000549                  contrato_c_clv
# 41          0.002877         0.000991             fecha_despido_c_clv
# 26          0.002780         0.000273                 tipo_prevencion
# 17          0.002729         0.000302  indemnizacion_20_dias_anio_ser
# 40          0.002675         0.000766             periodo_sal_int_clv
# 19          0.002609         0.000443                descanso_semanal
# 6           0.002590         0.000364                    tipo_jornada
# 33          0.002531         0.000517           incrementos_sal_c_clv
# 20          0.002376         0.000438            descanso_obligatorio
# 43          0.002314         0.000241            motivo_despido_c_clv
# 16          0.002245         0.000332                     horas_extra
# 15          0.002174         0.000339                       aguinaldo
# 8           0.002148         0.000347    periodicidad_horas_laboradas
# 9           0.001987         0.000244                   reinstalacion
# 38          0.001956         0.000288          especifican_dias_c_clv
# 36          0.001821         0.000203    horario_inicio_jornada_c_clv
# 45          0.001568         0.000227   presentado_tiempo_forma_c_clv
# 22          0.001535         0.000341                      utilidades
# 47          0.000810         0.000241          firma_trabajador_c_clv
# 13          0.000792         0.000219                      vacaciones
# 39          0.000680         0.000275                 salario_int_clv
# 12          0.000567         0.000103                prima_antiguedad
# 3           0.000403         0.000150            trabajador_confianza
# 14          0.000355         0.000184                prima_vacacional
# 18          0.000338         0.000063                 prima_dominical
# 35          0.000268         0.000056             lugar_trabajo_c_clv
# 44          0.000128         0.000145               cargo_despide_clv
# 27          0.000077         0.000133            derecho_propio_c_clv
# 1           0.000004         0.000011                   reclutamiento
# 21          0.000003         0.000062            cuotas_sar_imss_info

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingRegressor

# %%
# Grid de hiperparámetros evaluados
# ==============================================================================
param_grid = {'model__loss'             : ['least_squares', 'least_absolute_deviation'],
              'model__learning_rate'    : [0.001, 0.01, 0.1],
              'model__max_depth'        : [None, 1, 3, 5, 10, 20],
              'model__l2_regularization': [0, 1]
             }


# Gradient Boosting
HGB = Pipeline(steps=[('preprocessor', preprocessor),
                      ('model', HistGradientBoostingRegressor(
                        max_iter            = 1000,
                        # Activación de la parada temprana
                        early_stopping      = True,
                        scoring             = 'loss',
                        validation_fraction = 0.1,
                        n_iter_no_change    = 10,
                        tol                 = 1e-7,
                        random_state        = 123
                    ))])

# Búsqueda por grid search con validación cruzada
# ==============================================================================
grid = GridSearchCV(HGB,
        param_grid = param_grid,
        scoring    = 'neg_root_mean_squared_error',
        n_jobs     = multiprocessing.cpu_count() - 1,
        cv         = RepeatedKFold(n_splits=3, n_repeats=1, random_state=123), 
        refit      = True,
        verbose    = 0,
        return_train_score = True
       )

grid.fit(X = X_train, y = y_train)

# Resultados
# ==============================================================================
resultados = pd.DataFrame(grid.cv_results_)
resultados.filter(regex = '(param.*|mean_t|std_t)') \
    .drop(columns = 'params') \
    .sort_values('mean_test_score', ascending = False) \
    .head(4)
modelo_final = grid.best_estimator_

# %%
resultados = pd.DataFrame([
    explained_variance_score(y_test, modelo_final.predict(X_test), multioutput='uniform_average'),
    r2_score(y_test, modelo_final.predict(X_test), multioutput='variance_weighted'),
    mean_absolute_error(y_test, modelo_final.predict(X_test)),
    mean_squared_error(y_train, modelo_final.predict(X_train)),
    mean_squared_error(y_test, modelo_final.predict(X_test)),
    mean_absolute_percentage_error(y_test, modelo_final.predict(X_test))]
    )
resultados
# Out:
#           0
# 0  0.102030
# 1  0.102020
# 2  0.838119
# 3  1.058873
# 4  1.147196
# 5  0.127313

# %%
from xgboost import XGBRegressor

# %%
# Grid de hiperparámetros evaluados
# ==============================================================================
param_grid = {'model__max_depth'        : [None, 1, 3, 5, 10, 20],
              'model__subsample'        : [0.5, 1],
              'model__learning_rate'    : [0.001, 0.01, 0.1],
              'model__booster'          : ['gbtree']
             }


# Crear conjunto de validación
# ==============================================================================
np.random.seed(123)
idx_validacion = np.random.choice(
                    X_train.shape[0],
                    size= int(X_train.shape[0]*0.1),
                    replace=False
                 )

# %%
X_val = X_train.iloc[idx_validacion, :].copy()
y_val = y_train.iloc[idx_validacion].copy()

# %%
X_train_grid = X_train.reset_index(drop = True).drop(idx_validacion, axis = 0).copy()
y_train_grid = y_train.reset_index(drop = True).drop(idx_validacion, axis = 0).copy()

# %%
preprocessor_ = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)],
        remainder='passthrough')

# %%
encoder = preprocessor_.fit(X_train)

# %%
X_train_grid = encoder.transform(X_train_grid)

# %%
X_val = encoder.transform(X_val)

# %%
# XGBoost necesita pasar los paramétros específicos del entrenamiento al llamar
# al método .fit()
fit_params = {"model__early_stopping_rounds" : 5, 
              "model__eval_metric"           : "rmse", 
              "model__eval_set"              : [(X_val, y_val)],
              "model__verbose"               : 0
             }

# %%
XGB = Pipeline(steps=[('model', XGBRegressor(
                        n_estimators = 1000,
                        random_state = 123
                    ))])

# %%
# Búsqueda por grid search con validación cruzada
# ==============================================================================
grid = GridSearchCV(
        estimator  = XGB,
        param_grid = param_grid,
        scoring    = 'neg_root_mean_squared_error',
        n_jobs     = multiprocessing.cpu_count() - 1,
        cv         = RepeatedKFold(n_splits=3, n_repeats=1, random_state=123), 
        refit      = True,
        verbose    = 0,
        return_train_score = True
       )

# %%
grid.fit(X = X_train_grid, y = y_train_grid, **fit_params)
# Out:
# GridSearchCV(cv=RepeatedKFold(n_repeats=1, n_splits=3, random_state=123),
#              estimator=Pipeline(steps=[('model',
#                                         XGBRegressor(base_score=None,
#                                                      booster=None,
#                                                      colsample_bylevel=None,
#                                                      colsample_bynode=None,
#                                                      colsample_bytree=None,
#                                                      gamma=None, gpu_id=None,
#                                                      importance_type='gain',
#                                                      interaction_constraints=None,
#                                                      learning_rate=None,
#                                                      max_delta_step=None,
#                                                      max_depth=None,
#                                                      min_ch...
#                                                      random_state=123,
#                                                      reg_alpha=None,
#                                                      reg_lambda=None,
#                                                      scale_pos_weight=None,
#                                                      subsample=None,
#                                                      tree_method=None,
#                                                      validate_parameters=None,
#                                                      verbosity=None))]),
#              n_jobs=7,
#              param_grid={'model__booster': ['gbtree'],
#                          'model__learning_rate': [0.001, 0.01, 0.1],
#                          'model__max_depth': [None, 1, 3, 5, 10, 20],
#                          'model__subsample': [0.5, 1]},
#              return_train_score=True, scoring='neg_root_mean_squared_error')

# %%
# Resultados
# ==============================================================================
resultados = pd.DataFrame(grid.cv_results_)
resultados.filter(regex = '(param.*|mean_t|std_t)') \
    .drop(columns = 'params') \
    .sort_values('mean_test_score', ascending = False) \
    .head(4)
# Out:
#    param_model__booster param_model__learning_rate param_model__max_depth  \
# 16               gbtree                       0.01                      3
# 17               gbtree                       0.01                      3
# 29               gbtree                        0.1                      3
# 31               gbtree                        0.1                      5
#
#    param_model__subsample  mean_test_score  std_test_score  mean_train_score  \
# 16                    0.5        -1.105124        0.038562         -0.986502
# 17                      1        -1.106594        0.046242         -0.990411
# 29                      1        -1.106864        0.045188         -0.980592
# 31                      1        -1.112161        0.039312         -0.879848
#
#     std_train_score
# 16         0.024987
# 17         0.023036
# 29         0.024712
# 31         0.037192

# %%
modelo_final = grid.best_estimator_

# %%
resultados = pd.DataFrame([
    explained_variance_score(y_test, modelo_final.predict(encoder.transform(X_test)), multioutput='uniform_average'),
    r2_score(y_test, modelo_final.predict(encoder.transform(X_test)), multioutput='variance_weighted'),
    mean_absolute_error(y_test, modelo_final.predict(encoder.transform(X_test))),
    mean_squared_error(y_train, modelo_final.predict(encoder.transform(X_train))),
    mean_squared_error(y_test, modelo_final.predict(encoder.transform(X_test))),
    mean_absolute_percentage_error(y_test, modelo_final.predict(encoder.transform(X_test)))]
    )
resultados
# Out:
#           0
# 0  0.111382
# 1  0.100474
# 2  0.852415
# 3  1.032465
# 4  1.149171
# 5  0.124558

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RF = RandomForestRegressor(
            n_estimators = 10,
            criterion    = 'mse',
            max_depth    = None,
            max_features = 'auto',
            oob_score    = False,
            n_jobs       = -1,
            random_state = 123
         )

# Random Forests
RF = Pipeline(steps=[('preprocessor', preprocessor),
                      ('model', RF)])

RF.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('polynomial',
#                                                                    PolynomialFeatures(include_bias=False)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['sueldo_estadistico',
#                                                    'numero_horas_laboradas',
#                                                    'salarios_devengados_numero_dia',
#                                                    'num_demandados_totales',
#                                                    'num_demandados_completos',
#                                                    'num_abogados_proemio',
#                                                    'num_abogados_proemio_completos']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   ['tipo_abogado',
#                                                    'giro_empresa',
#                                                    'periodicidad_sueldo_estadistic',
#                                                    'tipo_jornada',
#                                                    'periodicidad_horas_laboradas',
#                                                    'accion_principal',
#                                                    'tipo_prevencion'])])),
#                 ('model',
#                  RandomForestRegressor(n_estimators=10, n_jobs=-1,
#                                        random_state=123))])

# %%
resultados = pd.DataFrame([
    explained_variance_score(y_test, RF.predict(X_test), multioutput='uniform_average'),
    r2_score(y_test, RF.predict(X_test), multioutput='variance_weighted'),
    mean_absolute_error(y_test, RF.predict(X_test)),
    mean_squared_error(y_test, RF.predict(X_test)),
    mean_absolute_percentage_error(y_test, RF.predict(X_test))]
    )
resultados
# Out:
#           0
# 0 -0.063985
# 1 -0.066411
# 2  0.913519
# 3  1.348736
# 4  0.132982

# %%
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD
from sklearn.cross_decomposition import PLSRegression
from sklearn.pipeline import make_pipeline

# %%
# PCR
pcr = Pipeline(steps=[('preprocessor', preprocessor),
                     ('components', TruncatedSVD(n_components=10)),
                      ('model', LinearRegression())])

pcr.fit(X_train, y_train)
hola = pd.DataFrame([pcr.predict(X_test), y_test])
hola

# %%
pcr.predict(X_test)

# %%
resultados = pd.DataFrame([
    explained_variance_score(y_test, pcr.predict(X_test), multioutput='uniform_average'),
    r2_score(y_test, pcr.predict(X_test), multioutput='variance_weighted'),
    mean_absolute_error(y_test, pcr.predict(X_test)),
    mean_squared_error(y_test, pcr.predict(X_test)),
    mean_absolute_percentage_error(y_test, pcr.predict(X_test))]
    )
resultados

# %%
from sklearn.preprocessing import FunctionTransformer

pls = Pipeline(steps=[('preprocessor', preprocessor),
                    ('model', PLSRegression(n_components=10))])

# %%
pls.fit(X_train, y_train)
pls.predict(X_test)

# %%
pred = pls.predict(X_test)
pred = pd.DataFrame(pred)
pred

# %%
resultados = pd.DataFrame([
    explained_variance_score(y_test, pred, multioutput='uniform_average'),
    r2_score(y_test, pls.predict(X_test), multioutput='variance_weighted'),
    mean_absolute_error(y_test, pred),
    mean_squared_error(y_test, pred),
    mean_absolute_percentage_error(y_test,pred)]
    )
resultados

# %%
from sklearn.ensemble import GradientBoostingClassifier

X_train, X_test, yd_train, yd_test = train_test_split(X, y_d, test_size=0.2,
                                                    random_state=0)

# %%
# Grid de hiperparámetros evaluados
# ==============================================================================
param_grid = {'model__n_estimators'  : [50, 100, 500, 1000],
              'model__max_features'  : ['auto', 'sqrt', 'log2'],
              'model__max_depth'     : [None, 1, 3, 5, 10, 20],
              'model__subsample'     : [0.5, 1],
              'model__learning_rate' : [0.001, 0.01, 0.1]
             }


GBC = Pipeline(steps=[('preprocessor', preprocessor),
                      ('model', GradientBoostingClassifier(random_state=123))])


# Búsqueda por grid search con validación cruzada
# ==============================================================================
grid = GridSearchCV(
        estimator  = GBC,
        param_grid = param_grid,
        scoring    = 'accuracy',
        n_jobs     = multiprocessing.cpu_count() - 1,
        cv         = RepeatedKFold(n_splits=3, n_repeats=1, random_state=123), 
        refit      = True,
        verbose    = 0,
        return_train_score = True
       )

grid.fit(X = X_train, y = yd_train)

# Resultados
# ==============================================================================
resultados = pd.DataFrame(grid.cv_results_)
resultados.filter(regex = '(param*|mean_t|std_t)') \
    .drop(columns = 'params') \
    .sort_values('mean_test_score', ascending = False) \
    .head(4)
# Out:
#     param_model__learning_rate param_model__max_depth  \
# 212                       0.01                      3
# 234                       0.01                      5
# 207                       0.01                      3
# 215                       0.01                      3
#
#     param_model__max_features param_model__n_estimators  \
# 212                      log2                       500
# 234                      log2                       100
# 207                      sqrt                      1000
# 215                      log2                      1000
#
#     param_model__subsample  mean_test_score  std_test_score  mean_train_score  \
# 212                    0.5         0.593864        0.016873          0.682692
# 234                    0.5         0.592033        0.027904          0.681090
# 207                      1         0.591575        0.020354          0.723672
# 215                      1         0.591117        0.024708          0.714286
#
#      std_train_score
# 212         0.006467
# 234         0.004498
# 207         0.010037
# 215         0.005855

# %%
modelo_final = grid.best_estimator_

# %%
from sklearn.metrics import accuracy_score
print(yd_test.mean())
print(accuracy_score(yd_test, modelo_final.predict(X_test)))
# Out:
# 0.48534798534798534
# 0.5860805860805861

# %%
importancia = permutation_importance(
                estimator    = modelo_final,
                X            = X_train,
                y            = yd_train,
                n_repeats    = 5,
                scoring      = 'accuracy',
                n_jobs       = multiprocessing.cpu_count() - 1,
                random_state = 123
             )

# Se almacenan los resultados (media y desviación) en un dataframe
df_importancia = pd.DataFrame(
                    {k: importancia[k] for k in ['importances_mean', 'importances_std']}
                 )
df_importancia['feature'] = X_train.columns
df_importancia.sort_values('importances_mean', ascending=False)

# %%
print('Finish')
